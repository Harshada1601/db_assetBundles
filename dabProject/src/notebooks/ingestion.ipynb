# %%
dbutils.widgets.text("catalog_name","")

# %%
c_name=dbutils.widgets.get("catalog_name")

# %%
print(c_name)

# %%
df=spark.sql(f"SELECT * FROM {c_name}.information_schema.columns")

# %%
display(df)
